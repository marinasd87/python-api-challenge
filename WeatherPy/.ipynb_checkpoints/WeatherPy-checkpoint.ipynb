# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from secret import api_key_w

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "/Users/marinaduarte/Documents/python-api-challenge/WeatherPy/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
coords = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs})

coords.head()
# Out:
#     latitude   longitude
# 0  -0.172355 -110.498522
# 1  43.156262 -116.053004
# 2 -43.581208   97.786154
# 3  26.565529 -136.078872
# 4  55.152670  -11.748072

# %%
# Check if we have a good population of lats and longs.
import seaborn

seaborn.set()

plt.hist(coords['latitude'])
plt.show()

# %%
plt.hist(coords['longitude'])
plt.show()

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
testresponse = requests.get(url + "appid=" + api_key_w + "&q=" + cities[0]).json()
testresponse
# Out:
# {'coord': {'lon': -105.2, 'lat': 20.7},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 305.26,
#   'feels_like': 308.07,
#   'temp_min': 305.15,
#   'temp_max': 305.37,
#   'pressure': 1011,
#   'humidity': 66},
#  'visibility': 10000,
#  'wind': {'speed': 5.1, 'deg': 220},
#  'clouds': {'all': 40},
#  'dt': 1603568079,
#  'sys': {'type': 1,
#   'id': 7156,
#   'country': 'MX',
#   'sunrise': 1603544375,
#   'sunset': 1603585798},
#  'timezone': -18000,
#  'id': 4004293,
#  'name': 'Ixtapa',
#  'cod': 200}

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
#columns = ["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]

City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []

for x in range(len(cities)):
    try:
        print(f"Processing record {x} | {cities[x]}")

    # Get one of the cities
        response = requests.get(url + "appid=" + api_key_w + "&q=" + cities[x]).json()

    # Save post's JSON
        City.append(response['name'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        
        time.sleep(1)
    except(KeyError, IndexError):
        print("City Not Found. Skipping...")
# Out:
# Processing record 0 | ixtapa
# Processing record 1 | mountain home
# Processing record 2 | busselton
# Processing record 3 | pacific grove
# Processing record 4 | westport
# Processing record 5 | rikitea
# Processing record 6 | henties bay
# Processing record 7 | ketchenery
# City Not Found. Skipping...
# Processing record 8 | egvekinot
# Processing record 9 | bathsheba
# Processing record 10 | faanui
# Processing record 11 | ushuaia
# Processing record 12 | vao
# Processing record 13 | huarmey
# Processing record 14 | ribeira grande
# Processing record 15 | khatanga
# Processing record 16 | atuona
# Processing record 17 | padang
# Processing record 18 | mardin
# Processing record 19 | palabuhanratu
# City Not Found. Skipping...
# Processing record 20 | contamana
# Processing record 21 | yerbogachen
# Processing record 22 | kodiak
# Processing record 23 | qaanaaq
# Processing record 24 | tiksi
# Processing record 25 | vila velha
# Processing record 26 | bonavista
# Processing record 27 | albany
# Processing record 28 | jamestown
# Processing record 29 | geraldton
# Processing record 30 | lorengau
# Processing record 31 | punta arenas
# Processing record 32 | morros
# Processing record 33 | yarkovo
# Processing record 34 | carnarvon
# Processing record 35 | mys shmidta
# City Not Found. Skipping...
# Processing record 36 | kajaani
# Processing record 37 | saleaula
# City Not Found. Skipping...
# Processing record 38 | mar del plata
# Processing record 39 | norman wells
# Processing record 40 | saint-philippe
# Processing record 41 | vaini
# Processing record 42 | upington
# Processing record 43 | zhangjiakou
# Processing record 44 | yairipok
# Processing record 45 | hannibal
# Processing record 46 | watsa
# Processing record 47 | bluff
# Processing record 48 | barrow
# Processing record 49 | new norfolk
# Processing record 50 | ahuimanu
# Processing record 51 | dikson
# Processing record 52 | san policarpo
# Processing record 53 | lebu
# Processing record 54 | liverpool
# Processing record 55 | viseu
# Processing record 56 | yulara
# Processing record 57 | abapo
# Processing record 58 | barentsburg
# City Not Found. Skipping...
# Processing record 59 | ullapool
# Processing record 60 | sao filipe
# Processing record 61 | arraial do cabo
# Processing record 62 | hoi an
# Processing record 63 | mataura
# Processing record 64 | esperance
# Processing record 65 | baykit
# Processing record 66 | harlingen
# Processing record 67 | ankang
# Processing record 68 | hilo
# Processing record 69 | avarua
# Processing record 70 | rize
# Processing record 71 | jijiga
# Processing record 72 | riohacha
# Processing record 73 | sinkat
# City Not Found. Skipping...
# Processing record 74 | touros
# Processing record 75 | nantucket
# Processing record 76 | crab hill
# City Not Found. Skipping...
# Processing record 77 | berlevag
# Processing record 78 | cidreira
# Processing record 79 | kaitangata
# Processing record 80 | saint-augustin
# Processing record 81 | belushya guba
# City Not Found. Skipping...
# Processing record 82 | san quintin
# Processing record 83 | chara
# Processing record 84 | west wendover
# Processing record 85 | kaeo
# Processing record 86 | ariquemes
# Processing record 87 | guadalupe y calvo
# Processing record 88 | raga
# Processing record 89 | esil
# Processing record 90 | south sioux city
# Processing record 91 | tungor
# Processing record 92 | bambous virieux
# Processing record 93 | etchoropo
# Processing record 94 | omboue
# Processing record 95 | corn island
# Processing record 96 | kapaa
# Processing record 97 | kahului
# Processing record 98 | orange
# Processing record 99 | bredasdorp
# Processing record 100 | los llanos de aridane
# Processing record 101 | olafsvik
# Processing record 102 | port lincoln
# Processing record 103 | pevek
# Processing record 104 | daru
# Processing record 105 | berovo
# Processing record 106 | hobart
# Processing record 107 | illoqqortoormiut
# City Not Found. Skipping...
# Processing record 108 | cape town
# Processing record 109 | provins
# Processing record 110 | sao jose da coroa grande
# Processing record 111 | narsaq
# Processing record 112 | waingapu
# Processing record 113 | jumla
# Processing record 114 | atikokan
# Processing record 115 | nanortalik
# Processing record 116 | quarai
# Processing record 117 | banjarmasin
# Processing record 118 | codrington
# Processing record 119 | ilulissat
# Processing record 120 | santa cruz del sur
# Processing record 121 | roebourne
# Processing record 122 | grand river south east
# City Not Found. Skipping...
# Processing record 123 | mopti
# Processing record 124 | bitung
# Processing record 125 | caloundra
# Processing record 126 | georgetown
# Processing record 127 | churachandpur
# Processing record 128 | matadi
# Processing record 129 | saskylakh
# Processing record 130 | meulaboh
# Processing record 131 | la ronge
# Processing record 132 | victoria
# Processing record 133 | puerto leguizamo
# Processing record 134 | makung
# City Not Found. Skipping...
# Processing record 135 | adrar
# Processing record 136 | kirakira
# Processing record 137 | wawa
# Processing record 138 | port-gentil
# Processing record 139 | castro
# Processing record 140 | hay river
# Processing record 141 | noyabrsk
# Processing record 142 | kieta
# Processing record 143 | east london
# Processing record 144 | abyek
# Processing record 145 | half moon bay
# Processing record 146 | bethel
# Processing record 147 | port alfred
# Processing record 148 | beringovskiy
# Processing record 149 | sorland
# Processing record 150 | manwath
# City Not Found. Skipping...
# Processing record 151 | santa maria da vitoria
# Processing record 152 | itarema
# Processing record 153 | pangnirtung
# Processing record 154 | guangyuan
# Processing record 155 | severo-kurilsk
# Processing record 156 | puerto ayora
# Processing record 157 | ada
# Processing record 158 | likasi
# Processing record 159 | hasaki
# Processing record 160 | iqaluit
# Processing record 161 | chagda
# City Not Found. Skipping...
# Processing record 162 | mehamn
# Processing record 163 | kamenka
# Processing record 164 | ostrovnoy
# Processing record 165 | bayan
# Processing record 166 | lolua
# City Not Found. Skipping...
# Processing record 167 | muisne
# Processing record 168 | chuy
# Processing record 169 | yellowknife
# Processing record 170 | tasiilaq
# Processing record 171 | flinders
# Processing record 172 | manjacaze
# Processing record 173 | qibili
# City Not Found. Skipping...
# Processing record 174 | tuktoyaktuk
# Processing record 175 | namatanai
# Processing record 176 | sangar
# Processing record 177 | disa
# Processing record 178 | kilemary
# Processing record 179 | clyde river
# Processing record 180 | ust-kamchatsk
# City Not Found. Skipping...
# Processing record 181 | huangchuan
# Processing record 182 | yantal
# Processing record 183 | faya
# Processing record 184 | ancud
# Processing record 185 | oriximina
# Processing record 186 | pulaski
# Processing record 187 | upernavik
# Processing record 188 | cherskiy
# Processing record 189 | umm lajj
# Processing record 190 | tuatapere
# Processing record 191 | samarai
# Processing record 192 | russell
# Processing record 193 | taolanaro
# City Not Found. Skipping...
# Processing record 194 | vallenar
# Processing record 195 | muros
# Processing record 196 | voh
# Processing record 197 | bahia blanca
# Processing record 198 | port elizabeth
# Processing record 199 | gazanjyk
# Processing record 200 | miastko
# Processing record 201 | dukat
# Processing record 202 | saldanha
# Processing record 203 | taltal
# Processing record 204 | lora del rio
# Processing record 205 | harper
# Processing record 206 | hermanus
# Processing record 207 | abu dhabi
# Processing record 208 | birao
# Processing record 209 | marienburg
# Processing record 210 | ola
# Processing record 211 | nome
# Processing record 212 | port moresby
# Processing record 213 | ahipara
# Processing record 214 | zalantun
# Processing record 215 | souillac
# Processing record 216 | constitucion
# Processing record 217 | amderma
# City Not Found. Skipping...
# Processing record 218 | college
# Processing record 219 | ponta delgada
# Processing record 220 | cockburn town
# Processing record 221 | narrabri
# Processing record 222 | midland
# Processing record 223 | praia
# Processing record 224 | palmira
# Processing record 225 | gilazi
# City Not Found. Skipping...
# Processing record 226 | moiyabana
# City Not Found. Skipping...
# Processing record 227 | sinnamary
# Processing record 228 | kuche
# City Not Found. Skipping...
# Processing record 229 | colesberg
# Processing record 230 | farmington
# Processing record 231 | guayaramerin
# Processing record 232 | mahebourg
# Processing record 233 | barsovo
# Processing record 234 | galle
# Processing record 235 | farakka
# Processing record 236 | priiskovyy
# Processing record 237 | kenora
# Processing record 238 | alihe
# Processing record 239 | tagusao
# Processing record 240 | purpe
# Processing record 241 | bela
# Processing record 242 | vaitupu
# City Not Found. Skipping...
# Processing record 243 | assiniboia
# Processing record 244 | havre-saint-pierre
# Processing record 245 | tautira
# Processing record 246 | thunder bay
# Processing record 247 | the valley
# Processing record 248 | jiddah
# City Not Found. Skipping...
# Processing record 249 | mangan
# Processing record 250 | emerald
# Processing record 251 | chifeng
# Processing record 252 | tessalit
# Processing record 253 | san jeronimo
# Processing record 254 | bengkulu
# Processing record 255 | bandarbeyla
# Processing record 256 | saint-georges
# Processing record 257 | kamyshevatskaya
# Processing record 258 | kharp
# Processing record 259 | kununurra
# Processing record 260 | mount gambier
# Processing record 261 | salalah
# Processing record 262 | chokurdakh
# Processing record 263 | alofi
# Processing record 264 | semenivka
# Processing record 265 | vostok
# Processing record 266 | ponnani
# Processing record 267 | vanimo
# Processing record 268 | sisimiut
# Processing record 269 | karratha
# Processing record 270 | agua dulce
# Processing record 271 | butaritari
# Processing record 272 | komsomolskiy
# Processing record 273 | tommot
# Processing record 274 | utiroa
# City Not Found. Skipping...
# Processing record 275 | port hawkesbury
# Processing record 276 | navolato
# Processing record 277 | portland
# Processing record 278 | nikolskoye
# Processing record 279 | ponta do sol
# Processing record 280 | alta floresta
# Processing record 281 | graciano sanchez
# Processing record 282 | bolungarvik
# City Not Found. Skipping...
# Processing record 283 | galesong
# Processing record 284 | northam
# Processing record 285 | tsihombe
# City Not Found. Skipping...
# Processing record 286 | suraabad
# Processing record 287 | grand-santi
# Processing record 288 | ngukurr
# City Not Found. Skipping...
# Processing record 289 | takoradi
# Processing record 290 | smidovich
# Processing record 291 | poya
# Processing record 292 | kloulklubed
# Processing record 293 | koslan
# Processing record 294 | sitka
# Processing record 295 | muravlenko
# Processing record 296 | vestmannaeyjar
# Processing record 297 | kavieng
# Processing record 298 | zhanakorgan
# Processing record 299 | obera
# Processing record 300 | asau
# Processing record 301 | talnakh
# Processing record 302 | dibaya
# City Not Found. Skipping...
# Processing record 303 | nalbari
# Processing record 304 | broome
# Processing record 305 | kyra
# Processing record 306 | isangel
# Processing record 307 | asbestos
# Processing record 308 | san miguel de cauri
# Processing record 309 | praya
# Processing record 310 | fortuna
# Processing record 311 | caramay
# Processing record 312 | yar-sale
# Processing record 313 | solnechnyy
# Processing record 314 | saveh
# Processing record 315 | cap malheureux
# Processing record 316 | cabo san lucas
# Processing record 317 | bacungan
# Processing record 318 | puerto carreno
# Processing record 319 | coruripe
# Processing record 320 | sarangani
# Processing record 321 | san cristobal
# Processing record 322 | kamenskoye
# City Not Found. Skipping...
# Processing record 323 | colonia
# Processing record 324 | matara
# Processing record 325 | marsa matruh
# Processing record 326 | cayenne
# Processing record 327 | kisangani
# Processing record 328 | agadez
# Processing record 329 | tashla
# Processing record 330 | attawapiskat
# City Not Found. Skipping...
# Processing record 331 | mangrol
# Processing record 332 | amboise
# Processing record 333 | lewiston
# Processing record 334 | georgiyevka
# Processing record 335 | xining
# Processing record 336 | carutapera
# Processing record 337 | cody
# Processing record 338 | denpasar
# Processing record 339 | thompson
# Processing record 340 | necochea
# Processing record 341 | port macquarie
# Processing record 342 | mullaitivu
# City Not Found. Skipping...
# Processing record 343 | bure
# Processing record 344 | rungata
# City Not Found. Skipping...
# Processing record 345 | parras
# City Not Found. Skipping...
# Processing record 346 | ewa beach
# Processing record 347 | klaksvik
# Processing record 348 | zhicheng
# Processing record 349 | bubaque
# Processing record 350 | isiro
# Processing record 351 | dongsheng
# Processing record 352 | longyearbyen
# Processing record 353 | kyzyl
# Processing record 354 | south venice
# Processing record 355 | deputatskiy
# Processing record 356 | kurchum
# Processing record 357 | ushtobe
# Processing record 358 | kirksville
# Processing record 359 | cockburn harbour
# City Not Found. Skipping...
# Processing record 360 | lata
# Processing record 361 | severo-yeniseyskiy
# Processing record 362 | manuk mangkaw
# Processing record 363 | wanganui
# Processing record 364 | banda aceh
# Processing record 365 | keti bandar
# Processing record 366 | show low
# Processing record 367 | san patricio
# Processing record 368 | ust-nera
# Processing record 369 | moron
# Processing record 370 | songjianghe
# Processing record 371 | carira
# Processing record 372 | wang saphung
# Processing record 373 | kabo
# Processing record 374 | lavrentiya
# Processing record 375 | ust-kuyga
# Processing record 376 | peterhead
# Processing record 377 | ipatovo
# Processing record 378 | hollins
# Processing record 379 | honningsvag
# Processing record 380 | dolbeau
# City Not Found. Skipping...
# Processing record 381 | hithadhoo
# Processing record 382 | malatya
# Processing record 383 | noumea
# Processing record 384 | renukut
# Processing record 385 | rorvik
# Processing record 386 | katsuura
# Processing record 387 | avare
# Processing record 388 | tambun
# Processing record 389 | marawi
# Processing record 390 | belmonte
# Processing record 391 | antsohihy
# Processing record 392 | kuusamo
# Processing record 393 | ferme-neuve
# Processing record 394 | labuhan
# Processing record 395 | socorro
# Processing record 396 | mocambique
# City Not Found. Skipping...
# Processing record 397 | qandahar
# City Not Found. Skipping...
# Processing record 398 | seymchan
# Processing record 399 | port blair
# Processing record 400 | yatou
# Processing record 401 | januaria
# Processing record 402 | samusu
# City Not Found. Skipping...
# Processing record 403 | numata
# Processing record 404 | airai
# Processing record 405 | yanchukan
# City Not Found. Skipping...
# Processing record 406 | houston
# Processing record 407 | bambanglipuro
# Processing record 408 | mahanoro
# Processing record 409 | westlock
# Processing record 410 | apomu
# Processing record 411 | bonthe
# Processing record 412 | richards bay
# Processing record 413 | invermere
# Processing record 414 | tabuk
# Processing record 415 | asfi
# Processing record 416 | milkovo
# Processing record 417 | mancheral
# Processing record 418 | maragogi
# Processing record 419 | senanga
# Processing record 420 | igarka
# Processing record 421 | batagay-alyta
# Processing record 422 | hamilton
# Processing record 423 | santarem
# Processing record 424 | pula
# Processing record 425 | temaraia
# City Not Found. Skipping...
# Processing record 426 | bulawayo
# Processing record 427 | kodinsk
# Processing record 428 | moyale
# Processing record 429 | karlstad
# Processing record 430 | riyadh
# Processing record 431 | garowe
# Processing record 432 | fairbanks
# Processing record 433 | hit
# Processing record 434 | klyuchi
# Processing record 435 | coquimbo
# Processing record 436 | coihaique
# Processing record 437 | bud
# Processing record 438 | makaleng
# Processing record 439 | rio gallegos
# Processing record 440 | oranjestad
# Processing record 441 | rio negrinho
# Processing record 442 | yumen
# Processing record 443 | juneau
# Processing record 444 | san ramon
# Processing record 445 | kenai
# Processing record 446 | pisco
# Processing record 447 | caucaia
# Processing record 448 | saint george
# Processing record 449 | leningradskiy
# Processing record 450 | morro bay
# Processing record 451 | namibe
# Processing record 452 | provideniya
# Processing record 453 | santander
# Processing record 454 | valparaiso
# Processing record 455 | zarinsk
# Processing record 456 | ust-koksa
# Processing record 457 | nelson bay
# Processing record 458 | plettenberg bay
# Processing record 459 | sur
# Processing record 460 | viedma
# Processing record 461 | khormuj
# City Not Found. Skipping...
# Processing record 462 | alirajpur
# Processing record 463 | miesbach
# Processing record 464 | aklavik
# Processing record 465 | ust-kulom
# Processing record 466 | panzhihua
# Processing record 467 | luderitz
# Processing record 468 | skelleftea
# Processing record 469 | husavik
# Processing record 470 | starodubskoye
# Processing record 471 | lamu
# Processing record 472 | coahuayana
# Processing record 473 | hofn
# Processing record 474 | dingle
# Processing record 475 | dzilam gonzalez
# Processing record 476 | moose factory
# Processing record 477 | caravelas
# Processing record 478 | gogrial
# Processing record 479 | lermontovka
# Processing record 480 | brae
# Processing record 481 | ambilobe
# Processing record 482 | formiga
# Processing record 483 | hervey bay
# Processing record 484 | iralaya
# Processing record 485 | praia da vitoria
# Processing record 486 | el rosario
# Processing record 487 | cascais
# Processing record 488 | balakliya
# Processing record 489 | mori
# Processing record 490 | darnah
# Processing record 491 | fukue
# Processing record 492 | maryborough
# Processing record 493 | lalibela
# Processing record 494 | balkhash
# Processing record 495 | puerto baquerizo moreno
# Processing record 496 | agva
# City Not Found. Skipping...
# Processing record 497 | atambua
# Processing record 498 | novouzensk
# Processing record 499 | hami
# Processing record 500 | skali
# City Not Found. Skipping...
# Processing record 501 | hokitika
# Processing record 502 | kigorobya
# Processing record 503 | sakakah
# Processing record 504 | scottsbluff
# Processing record 505 | sawtell
# Processing record 506 | oyama
# Processing record 507 | ostersund
# Processing record 508 | turinskaya sloboda
# Processing record 509 | negombo
# Processing record 510 | poum
# Processing record 511 | louisbourg
# City Not Found. Skipping...
# Processing record 512 | bireun
# Processing record 513 | mtwara
# Processing record 514 | knysna
# Processing record 515 | satitoa
# City Not Found. Skipping...
# Processing record 516 | north platte
# Processing record 517 | goderich
# Processing record 518 | jiwani
# Processing record 519 | tres picos
# Processing record 520 | itacarambi
# Processing record 521 | gillette
# Processing record 522 | todos santos
# Processing record 523 | kaikalur
# Processing record 524 | dombas
# Processing record 525 | nizhneyansk
# City Not Found. Skipping...
# Processing record 526 | manacapuru
# Processing record 527 | tadine
# Processing record 528 | waihi beach
# Processing record 529 | katherine
# Processing record 530 | sorvag
# City Not Found. Skipping...
# Processing record 531 | kaoma
# Processing record 532 | igrim
# Processing record 533 | sumkino
# Processing record 534 | kifri
# Processing record 535 | mabaruma
# Processing record 536 | pocatello
# Processing record 537 | bjornevatn
# Processing record 538 | tual
# Processing record 539 | koumac
# Processing record 540 | broken hill
# Processing record 541 | yokadouma
# Processing record 542 | tacuarembo
# Processing record 543 | ormara
# Processing record 544 | clarence town
# Processing record 545 | racoasa
# Processing record 546 | bilma
# Processing record 547 | zhigansk
# Processing record 548 | sompeta
# Processing record 549 | catuday
# Processing record 550 | scalloway
# City Not Found. Skipping...
# Processing record 551 | watertown
# Processing record 552 | doha
# Processing record 553 | risor
# Processing record 554 | san carlos
# Processing record 555 | mugur-aksy
# Processing record 556 | livramento
# Processing record 557 | palkaka
# City Not Found. Skipping...
# Processing record 558 | bukachacha
# Processing record 559 | vardo
# Processing record 560 | antofagasta
# Processing record 561 | ouesso
# Processing record 562 | torbay
# Processing record 563 | bargal
# City Not Found. Skipping...
# Processing record 564 | arroyo
# Processing record 565 | prince rupert
# Processing record 566 | florianopolis
# Processing record 567 | malindi
# Processing record 568 | orzu
# Processing record 569 | grand gaube
# Processing record 570 | byron bay
# Processing record 571 | nayoro
# Processing record 572 | yanam
# Processing record 573 | kuryk
# Processing record 574 | matagami
# Processing record 575 | salym
# Processing record 576 | te anau
# Processing record 577 | agadir
# Processing record 578 | itaituba
# Processing record 579 | kagoro
# Processing record 580 | peleduy
# Processing record 581 | qaqortoq
# Processing record 582 | sechura
# Processing record 583 | umm durman
# City Not Found. Skipping...
# Processing record 584 | tevaitoa
# Processing record 585 | arlit
# Processing record 586 | palmer
# Processing record 587 | velyka oleksandrivka
# Processing record 588 | ukiah
# Processing record 589 | nhulunbuy
# Processing record 590 | mokrousovo
# Processing record 591 | sorong
# Processing record 592 | vienna
# Processing record 593 | chaoyang
# Processing record 594 | bouna
# Processing record 595 | quibor
# Processing record 596 | lasa
# Processing record 597 | trairi
# Processing record 598 | fethiye
# Processing record 599 | qovlar
# Processing record 600 | uwayl
# City Not Found. Skipping...
# Processing record 601 | grindavik
# Processing record 602 | gurgan
# City Not Found. Skipping...
# Processing record 603 | gezing
# Processing record 604 | shawnee
# Processing record 605 | paamiut
# Processing record 606 | aliwal north
# Processing record 607 | pingliang
# Processing record 608 | marsh harbour
# Processing record 609 | arman
# Processing record 610 | zhanatas
# City Not Found. Skipping...

# %%
#Converts a Kelvin temperature to Fahrenheit
def k_to_f(temp):
    return temp * 9/5 - 459.67

#Converts a meters/s speed to miles/hour
def mps_to_mph(speed):
    return speed * 2.23694

weather_dict = {
    "City": City,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp": Max_Temp,
    "Humidity": Humidity,
    "Cloudiness": Cloudiness,
    "Wind Speed": Wind_Speed,
    "Country": Country,
    "Date": Date,
}
weather_data = pd.DataFrame(weather_dict)
weather_data['Max Temp'] = k_to_f(weather_data['Max Temp'])
weather_data['Wind Speed'] = mps_to_mph(weather_data['Wind Speed'])
weather_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Ixtapa  20.70 -105.20    89.996        66          40   11.408394
# 1  Mountain Home  43.13 -115.69    46.400        47          90   18.342908
# 2      Busselton -33.65  115.33    57.002        52          85   10.267555
# 3  Pacific Grove  36.62 -121.92    66.992        72          75    4.697574
# 4       Westport  41.14  -73.36    66.992        82          75   10.289924
#
#   Country        Date
# 0      MX  1603568093
# 1      US  1603567958
# 2      AU  1603568096
# 3      US  1603567900
# 4      US  1603568098

# %%
weather_data.to_csv('cities.csv')

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    20.326984   17.937074   59.579425   73.928187   57.001795    8.431376
# std     33.470416   92.478306   21.436815   20.367802   38.579335    5.919615
# min    -54.800000 -179.170000    5.684000    1.000000    0.000000    0.469757
# 25%     -8.650000  -63.470000   42.944000   64.000000   20.000000    4.317294
# 50%     24.330000   24.800000   64.994000   79.000000   75.000000    7.158208
# 75%     48.210000  100.340000   77.216000   90.000000   93.000000   11.408394
# max     78.220000  179.320000  100.994000  100.000000  100.000000   43.240050
#
#                Date
# count  5.570000e+02
# mean   1.603568e+09
# std    2.006158e+02
# min    1.603568e+09
# 25%    1.603568e+09
# 50%    1.603568e+09
# 75%    1.603569e+09
# max    1.603569e+09

# %%
weather_data2 = weather_data.loc[weather_data['Humidity']<101]
weather_data2.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    20.326984   17.937074   59.579425   73.928187   57.001795    8.431376
# std     33.470416   92.478306   21.436815   20.367802   38.579335    5.919615
# min    -54.800000 -179.170000    5.684000    1.000000    0.000000    0.469757
# 25%     -8.650000  -63.470000   42.944000   64.000000   20.000000    4.317294
# 50%     24.330000   24.800000   64.994000   79.000000   75.000000    7.158208
# 75%     48.210000  100.340000   77.216000   90.000000   93.000000   11.408394
# max     78.220000  179.320000  100.994000  100.000000  100.000000   43.240050
#
#                Date
# count  5.570000e+02
# mean   1.603568e+09
# std    2.006158e+02
# min    1.603568e+09
# 25%    1.603568e+09
# 50%    1.603568e+09
# 75%    1.603569e+09
# max    1.603569e+09

# %%
plt.scatter(weather_data2['Lat'], weather_data2['Max Temp'])
plt.xlabel("Latitud")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (10/24/2020)")
#plt.show()
plt.savefig('lat vs max temp.png')

# %%
#As we go further away in any direction from Lat = 0 the Max Temps are lower. Max Temps around Lat = 0 are higher.
#Max temps are lower the higher the latitud is

# %%
plt.scatter(weather_data2['Lat'], weather_data2['Humidity'])
plt.xlabel("Latitud")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (10/24/2020)")
#plt.show()
plt.savefig('lat vs humidity.png')

# %%
#There is no correlation between Latitud and humidity. 
#Most of the cities in my sample seems to have a humidity of 60% and higher

# %%
plt.scatter(weather_data2['Lat'], weather_data2['Cloudiness'])
plt.xlabel("Latitud")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (10/24/2020)")
#plt.show()
plt.savefig('lat vs cloudiness.png')

# %%
#There is no correlation between Latitud and cloudiness

# %%
plt.scatter(weather_data2['Lat'], weather_data2['Wind Speed'])
plt.xlabel("Latitud")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (10/24/2020)")
#plt.show()
plt.savefig('lat vs wind speed.png')

# %%
#There is no correlation between Latitud and wind speed
#Most of the cities in my sample have a wind speed of under 10 mph

# %%
weather_dataN = weather_data2.loc[weather_data['Lat']>0]
weather_dataS = weather_data2.loc[weather_data['Lat']<=0]

# %%
# Perform a linear regression on temperature vs. latitude N
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataN['Lat'], weather_dataN['Max Temp'])

# Get regression values
regress_values = weather_dataN['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataN['Lat'],weather_dataN['Max Temp'])
plt.plot(weather_dataN['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7650519660807903

# %%
#There is a negative correlation between the latitud and max temps in the northern hemisphere. 
#The higher the latitud the lower the temperature

# %%
# Perform a linear regression on temperature vs. latitude S
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataS['Lat'], weather_dataS['Max Temp'])

# Get regression values
regress_values = weather_dataS['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataS['Lat'],weather_dataS['Max Temp'])
plt.plot(weather_dataS['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.5055345569089812

# %%
#There is a positive correlation between the latitud and max temps in the southern hemisphere. 
#The higher the latitud the higher the temperature

# %%
# Perform a linear regression on humidity vs. latitude N
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataN['Lat'], weather_dataN['Humidity'])

# Get regression values
regress_values = weather_dataN['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataN['Lat'],weather_dataN['Humidity'])
plt.plot(weather_dataN['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.10492538957499929

# %%
#There is a small positive correlation between the latitud and humidity in the northern hemisphere. 
#The higher the latitud the higher the humidity

# %%
# Perform a linear regression on humidity vs. latitude s
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataS['Lat'], weather_dataS['Humidity'])

# Get regression values
regress_values = weather_dataS['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataS['Lat'],weather_dataS['Humidity'])
plt.plot(weather_dataS['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0008892197714580194

# %%
#There is no correlation between humidity and latitud on the southern hemisphere

# %%
# Perform a linear regression on cloudiness vs. latitude N
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataN['Lat'], weather_dataN['Cloudiness'])

# Get regression values
regress_values = weather_dataN['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataN['Lat'],weather_dataN['Cloudiness'])
plt.plot(weather_dataN['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.01869244664963726

# %%
#There is a small positive correlation between the latitud and cloudiness in the northern hemisphere. 
#The higher the latitud the higher the cloudiness

# %%
# Perform a linear regression on cloudiness vs. latitude s
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataS['Lat'], weather_dataS['Cloudiness'])

# Get regression values
regress_values = weather_dataS['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataS['Lat'],weather_dataS['Cloudiness'])
plt.plot(weather_dataS['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0016329070558552307

# %%
#There is a extremely low correlation between cloudiness and latitud on the southern hemisphere

# %%
# Perform a linear regression on wind speed vs. latitude N
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataN['Lat'], weather_dataN['Wind Speed'])

# Get regression values
regress_values = weather_dataN['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataN['Lat'],weather_dataN['Wind Speed'])
plt.plot(weather_dataN['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04177115345326108

# %%
#There is a low (positive) correlation between wind speed and latitud on the northern hemisphere

# %%
# Perform a linear regression on wind speed vs. latitude S
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_dataS['Lat'], weather_dataS['Wind Speed'])

# Get regression values
regress_values = weather_dataS['Lat'] * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(weather_dataS['Lat'],weather_dataS['Wind Speed'])
plt.plot(weather_dataS['Lat'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.017740871230388464

# %%
#There is a low (negative) correlation between wind speed and latitud on the southern hemisphere
